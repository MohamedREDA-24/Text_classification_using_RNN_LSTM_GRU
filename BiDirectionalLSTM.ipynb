# %%
import csv
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Dropout, Embedding, Conv1D, MaxPooling1D, SimpleRNN, BatchNormalization

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
vocab_size = 5000
embedding_dim = 64
max_length = 200
oov_tok = '<OOV>' #  Out of Vocabulary , 1 for test input that was not trained
training_portion = 0.8

# %%
articles = []
labels = []

with open("bbc-text.csv", 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    for row in reader:
        labels.append(row[0])
        article = row[1]
        for word in STOPWORDS:
            token = ' ' + word + ' '
            article = article.replace(token, ' ')
        articles.append(article)

# %%
len(labels),len(articles)
# Out:
# (1837, 1837)

# %%
unique_labels = set(labels)
print(unique_labels)
# Out:
# {'entertainment', 'business', 'politics', 'sport', 'tech'}

# %%
articles[0]
# Out:
# 'tv future hands viewers home theatre systems  plasma high-definition tvs  digital video recorders moving living room  way people watch tv radically different five years  time.  according expert panel gathered annual consumer electronics show las vegas discuss new technologies impact one favourite pastimes. us leading trend  programmes content delivered viewers via home networks  cable  satellite  telecoms companies  broadband service providers front rooms portable devices.  one talked-about technologies ces digital personal video recorders (dvr pvr). set-top boxes  like us tivo uk sky+ system  allow people record  store  play  pause forward wind tv programmes want.  essentially  technology allows much personalised tv. also built-in high-definition tv sets  big business japan us  slower take europe lack high-definition programming. people forward wind adverts  also forget abiding network channel schedules  putting together a-la-carte entertainment. us networks cable satellite companies worried means terms advertising revenues well  brand identity  viewer loyalty channels. although us leads technology moment  also concern raised europe  particularly growing uptake services like sky+.  happens today  see nine months years  time uk   adam hume  bbc broadcast futurologist told bbc news website. likes bbc  issues lost advertising revenue yet. pressing issue moment commercial uk broadcasters  brand loyalty important everyone.  talking content brands rather network brands   said tim hanlon  brand communications firm starcom mediavest.  reality broadband connections  anybody producer content.  added:  challenge hard promote programme much choice.   means  said stacey jolna  senior vice president tv guide tv group  way people find content want watch simplified tv viewers. means networks  us terms  channels could take leaf google book search engine future  instead scheduler help people find want watch. kind channel model might work younger ipod generation used taking control gadgets play them. might suit everyone  panel recognised. older generations comfortable familiar schedules channel brands know getting. perhaps want much choice put hands  mr hanlon suggested.  end  kids diapers pushing buttons already - everything possible available   said mr hanlon.  ultimately  consumer tell market want.   50 000 new gadgets technologies showcased ces  many enhancing tv-watching experience. high-definition tv sets everywhere many new models lcd (liquid crystal display) tvs launched dvr capability built  instead external boxes. one example launched show humax 26-inch lcd tv 80-hour tivo dvr dvd recorder. one us biggest satellite tv companies  directtv  even launched branded dvr show 100-hours recording capability  instant replay  search function. set pause rewind tv 90 hours. microsoft chief bill gates announced pre-show keynote speech partnership tivo  called tivotogo  means people play recorded programmes windows pcs mobile devices. reflect increasing trend freeing multimedia people watch want  want.'

# %%
train_size = int(len(articles) * training_portion)

train_articles = articles[0: train_size]
train_labels = labels[0: train_size]

validation_articles = articles[train_size:]
validation_labels = labels[train_size:]

# %%
print('train_articles' ,len(train_articles))
print('train_labels', len(train_labels))
print('validation_articles', len(validation_articles))
print('validation_labels', len(validation_labels))
# Out:
# train_articles 1469
# train_labels 1469
# validation_articles 368
# validation_labels 368

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_articles)
word_index = tokenizer.word_index

# %%
len(word_index)
# Out:
# 25230

# %%
word_index
# Out:
# {'<OOV>': 1,
#  'said': 2,
#  'mr': 3,
#  'would': 4,
#  'year': 5,
#  'also': 6,
#  'people': 7,
#  'new': 8,
#  'us': 9,
#  'one': 10,
#  'could': 11,
#  'last': 12,
#  'time': 13,
#  'first': 14,
#  'government': 15,
#  'two': 16,
#  'world': 17,
#  'uk': 18,
#  'years': 19,
#  'film': 20,
#  'make': 21,
#  'best': 22,
#  'told': 23,
#  'music': 24,
#  'made': 25,
#  'get': 26,
#  'game': 27,
#  'many': 28,
#  'like': 29,
#  'back': 30,
#  '000': 31,
#  '1': 32,
#  'three': 33,
#  'labour': 34,
#  'bbc': 35,
#  'next': 36,
#  'well': 37,
#  'take': 38,
#  'added': 39,
#  'number': 40,
#  'set': 41,
#  'way': 42,
#  '2': 43,
#  'says': 44,
#  'company': 45,
#  'may': 46,
#  'market': 47,
#  'home': 48,
#  'election': 49,
#  'work': 50,
#  'going': 51,
#  'still': 52,
#  'much': 53,
#  'show': 54,
#  'good': 55,
#  '2004': 56,
#  'firm': 57,
#  'games': 58,
#  'england': 59,
#  'win': 60,
#  'go': 61,
#  'since': 62,
#  'million': 63,
#  'think': 64,
#  'public': 65,
#  'second': 66,
#  'week': 67,
#  'say': 68,
#  'party': 69,
#  'play': 70,
#  '6': 71,
#  'top': 72,
#  'want': 73,
#  'technology': 74,
#  'part': 75,
#  'use': 76,
#  'see': 77,
#  'blair': 78,
#  '3': 79,
#  'high': 80,
#  'however': 81,
#  '4': 82,
#  'minister': 83,
#  'country': 84,
#  'european': 85,
#  'tv': 86,
#  'five': 87,
#  'british': 88,
#  '10': 89,
#  'news': 90,
#  'end': 91,
#  'group': 92,
#  'players': 93,
#  'economy': 94,
#  'growth': 95,
#  'expected': 96,
#  'put': 97,
#  'half': 98,
#  'used': 99,
#  'even': 100,
#  'service': 101,
#  '5': 102,
#  'old': 103,
#  'plans': 104,
#  'net': 105,
#  'brown': 106,
#  'already': 107,
#  'sales': 108,
#  'long': 109,
#  'chief': 110,
#  'four': 111,
#  'director': 112,
#  'digital': 113,
#  'services': 114,
#  'money': 115,
#  'months': 116,
#  'former': 117,
#  'tax': 118,
#  'london': 119,
#  'system': 120,
#  'companies': 121,
#  'six': 122,
#  'right': 123,
#  'britain': 124,
#  'day': 125,
#  'come': 126,
#  'according': 127,
#  'need': 128,
#  'business': 129,
#  'deal': 130,
#  'big': 131,
#  'place': 132,
#  'industry': 133,
#  'mobile': 134,
#  'firms': 135,
#  'including': 136,
#  'team': 137,
#  '2005': 138,
#  'wales': 139,
#  'third': 140,
#  'international': 141,
#  'report': 142,
#  'final': 143,
#  'users': 144,
#  'based': 145,
#  'help': 146,
#  'move': 147,
#  'life': 148,
#  'economic': 149,
#  'month': 150,
#  'hit': 151,
#  'video': 152,
#  'software': 153,
#  'called': 154,
#  'bank': 155,
#  'record': 156,
#  'really': 157,
#  '7': 158,
#  'france': 159,
#  '2003': 160,
#  'start': 161,
#  'future': 162,
#  'europe': 163,
#  'around': 164,
#  'online': 165,
#  'without': 166,
#  'another': 167,
#  'ireland': 168,
#  'came': 169,
#  'know': 170,
#  'took': 171,
#  'open': 172,
#  'club': 173,
#  'howard': 174,
#  'general': 175,
#  'got': 176,
#  'up': 177,
#  'law': 178,
#  'china': 179,
#  'far': 180,
#  'spokesman': 181,
#  'side': 182,
#  'give': 183,
#  'great': 184,
#  'united': 185,
#  'making': 186,
#  'radio': 187,
#  'media': 188,
#  'decision': 189,
#  'court': 190,
#  'president': 191,
#  'state': 192,
#  'campaign': 193,
#  'countries': 194,
#  'better': 195,
#  'become': 196,
#  'despite': 197,
#  'likely': 198,
#  'data': 199,
#  'found': 200,
#  'away': 201,
#  'national': 202,
#  'saying': 203,
#  'player': 204,
#  'action': 205,
#  'executive': 206,
#  'lot': 207,
#  'line': 208,
#  'able': 209,
#  'office': 210,
#  'it': 211,
#  'run': 212,
#  'security': 213,
#  'internet': 214,
#  'phone': 215,
#  'real': 216,
#  'left': 217,
#  'star': 218,
#  'oil': 219,
#  'role': 220,
#  'prime': 221,
#  'offer': 222,
#  'figures': 223,
#  '20': 224,
#  'whether': 225,
#  'every': 226,
#  'computer': 227,
#  'using': 228,
#  'playing': 229,
#  'information': 230,
#  'given': 231,
#  'rise': 232,
#  'biggest': 233,
#  'cup': 234,
#  'microsoft': 235,
#  'cost': 236,
#  'times': 237,
#  'prices': 238,
#  'pay': 239,
#  'although': 240,
#  'john': 241,
#  'man': 242,
#  'case': 243,
#  'seen': 244,
#  'later': 245,
#  'anti': 246,
#  'hard': 247,
#  'foreign': 248,
#  'nations': 249,
#  'played': 250,
#  'taking': 251,
#  'face': 252,
#  'michael': 253,
#  'analysts': 254,
#  'broadband': 255,
#  'increase': 256,
#  'look': 257,
#  'leader': 258,
#  'days': 259,
#  'lost': 260,
#  'never': 261,
#  'believe': 262,
#  'interest': 263,
#  'legal': 264,
#  'house': 265,
#  'past': 266,
#  'january': 267,
#  'secretary': 268,
#  'support': 269,
#  'control': 270,
#  'rights': 271,
#  'local': 272,
#  'chancellor': 273,
#  'important': 274,
#  'bill': 275,
#  'season': 276,
#  'december': 277,
#  'films': 278,
#  'less': 279,
#  'recent': 280,
#  'e': 281,
#  'financial': 282,
#  'children': 283,
#  'due': 284,
#  'ahead': 285,
#  'shares': 286,
#  'lord': 287,
#  'little': 288,
#  'cut': 289,
#  'research': 290,
#  'strong': 291,
#  'power': 292,
#  'early': 293,
#  'awards': 294,
#  'earlier': 295,
#  'tory': 296,
#  'quarter': 297,
#  'match': 298,
#  'something': 299,
#  'south': 300,
#  'award': 301,
#  'free': 302,
#  'scotland': 303,
#  'held': 304,
#  'working': 305,
#  'thought': 306,
#  'went': 307,
#  'try': 308,
#  'return': 309,
#  'change': 310,
#  'currently': 311,
#  'looking': 312,
#  'eu': 313,
#  'issue': 314,
#  'access': 315,
#  'current': 316,
#  'rate': 317,
#  'yet': 318,
#  'trade': 319,
#  'share': 320,
#  'programme': 321,
#  'meeting': 322,
#  'content': 323,
#  'find': 324,
#  'keep': 325,
#  'series': 326,
#  'following': 327,
#  'latest': 328,
#  'across': 329,
#  '0': 330,
#  'almost': 331,
#  'full': 332,
#  'problems': 333,
#  'lead': 334,
#  'major': 335,
#  'spending': 336,
#  'enough': 337,
#  'among': 338,
#  'sale': 339,
#  'website': 340,
#  'ever': 341,
#  'ago': 342,
#  'chance': 343,
#  'injury': 344,
#  'demand': 345,
#  'different': 346,
#  'personal': 347,
#  'behind': 348,
#  'sunday': 349,
#  'chelsea': 350,
#  'key': 351,
#  '12': 352,
#  '9': 353,
#  'jobs': 354,
#  'tories': 355,
#  'budget': 356,
#  '11': 357,
#  'williams': 358,
#  'david': 359,
#  'performance': 360,
#  'india': 361,
#  'means': 362,
#  'might': 363,
#  'minutes': 364,
#  'must': 365,
#  'police': 366,
#  'low': 367,
#  '30': 368,
#  'ms': 369,
#  'sold': 370,
#  '8': 371,
#  'getting': 372,
#  'chairman': 373,
#  'announced': 374,
#  'job': 375,
#  'winning': 376,
#  'problem': 377,
#  'coach': 378,
#  'clear': 379,
#  'price': 380,
#  'network': 381,
#  'asked': 382,
#  'continue': 383,
#  'tuesday': 384,
#  'point': 385,
#  'american': 386,
#  'rugby': 387,
#  'union': 388,
#  'always': 389,
#  'actor': 390,
#  'manager': 391,
#  'coming': 392,
#  'japan': 393,
#  'rather': 394,
#  'dollar': 395,
#  'production': 396,
#  'huge': 397,
#  'women': 398,
#  'investment': 399,
#  'band': 400,
#  'hold': 401,
#  'mark': 402,
#  'things': 403,
#  'men': 404,
#  'plan': 405,
#  'consumer': 406,
#  'claims': 407,
#  'head': 408,
#  'victory': 409,
#  'rates': 410,
#  'allow': 411,
#  'today': 412,
#  'within': 413,
#  'tony': 414,
#  'known': 415,
#  'released': 416,
#  'available': 417,
#  'march': 418,
#  'global': 419,
#  'title': 420,
#  'term': 421,
#  'taken': 422,
#  'possible': 423,
#  'least': 424,
#  'friday': 425,
#  'mail': 426,
#  'main': 427,
#  'february': 428,
#  'include': 429,
#  'political': 430,
#  'done': 431,
#  'yukos': 432,
#  'wednesday': 433,
#  'statement': 434,
#  'war': 435,
#  '15': 436,
#  'costs': 437,
#  'members': 438,
#  'warned': 439,
#  '18': 440,
#  'buy': 441,
#  '50': 442,
#  'previous': 443,
#  'november': 444,
#  'several': 445,
#  'customers': 446,
#  'council': 447,
#  'monday': 448,
#  'live': 449,
#  'running': 450,
#  'result': 451,
#  'league': 452,
#  'list': 453,
#  '2001': 454,
#  'though': 455,
#  'policy': 456,
#  'weeks': 457,
#  'beat': 458,
#  'saturday': 459,
#  'forward': 460,
#  'human': 461,
#  'form': 462,
#  'young': 463,
#  'pc': 464,
#  'apple': 465,
#  'issues': 466,
#  'book': 467,
#  'act': 468,
#  'networks': 469,
#  'saw': 470,
#  'consumers': 471,
#  'fans': 472,
#  'success': 473,
#  'led': 474,
#  'french': 475,
#  'bid': 476,
#  'cash': 477,
#  'search': 478,
#  'co': 479,
#  'recently': 480,
#  'committee': 481,
#  'football': 482,
#  'small': 483,
#  'evidence': 484,
#  'vote': 485,
#  'trying': 486,
#  'difficult': 487,
#  'family': 488,
#  'eight': 489,
#  'others': 490,
#  'thing': 491,
#  'web': 492,
#  'name': 493,
#  'close': 494,
#  'phones': 495,
#  'mps': 496,
#  'rules': 497,
#  'level': 498,
#  '25': 499,
#  'wanted': 500,
#  'let': 501,
#  'ministers': 502,
#  'sir': 503,
#  'debt': 504,
#  'aid': 505,
#  'needed': 506,
#  'comes': 507,
#  'italy': 508,
#  'trial': 509,
#  'centre': 510,
#  'total': 511,
#  'short': 512,
#  'fact': 513,
#  'health': 514,
#  'jones': 515,
#  'popular': 516,
#  'race': 517,
#  'choice': 518,
#  'christmas': 519,
#  'version': 520,
#  'agreed': 521,
#  'cannot': 522,
#  'dvd': 523,
#  'liverpool': 524,
#  'calls': 525,
#  'hope': 526,
#  'festival': 527,
#  'call': 528,
#  'claim': 529,
#  'meet': 530,
#  'higher': 531,
#  'feel': 532,
#  'development': 533,
#  'goal': 534,
#  'board': 535,
#  'event': 536,
#  'competition': 537,
#  'involved': 538,
#  'v': 539,
#  'stage': 540,
#  'fourth': 541,
#  'single': 542,
#  'failed': 543,
#  'actress': 544,
#  'charles': 545,
#  'black': 546,
#  'lib': 547,
#  'instead': 548,
#  'shows': 549,
#  'site': 550,
#  'claimed': 551,
#  'showed': 552,
#  'to': 553,
#  'bt': 554,
#  'movie': 555,
#  'york': 556,
#  'wants': 557,
#  'profits': 558,
#  'thursday': 559,
#  'sony': 560,
#  'sites': 561,
#  'together': 562,
#  'conference': 563,
#  'october': 564,
#  'stock': 565,
#  'russian': 566,
#  'annual': 567,
#  'opening': 568,
#  'project': 569,
#  'prize': 570,
#  'points': 571,
#  'liberal': 572,
#  'paul': 573,
#  'parties': 574,
#  'large': 575,
#  'on': 576,
#  '2002': 577,
#  'giant': 578,
#  'out': 579,
#  'sure': 580,
#  'fall': 581,
#  'career': 582,
#  'largest': 583,
#  'launch': 584,
#  'tour': 585,
#  'paid': 586,
#  'commission': 587,
#  'them': 588,
#  '40': 589,
#  'africa': 590,
#  'quite': 591,
#  'television': 592,
#  'stop': 593,
#  'nothing': 594,
#  'in': 595,
#  'boss': 596,
#  'city': 597,
#  'gordon': 598,
#  'break': 599,
#  'started': 600,
#  'virus': 601,
#  'album': 602,
#  '100': 603,
#  '17': 604,
#  'remain': 605,
#  'boost': 606,
#  'stars': 607,
#  'ball': 608,
#  'received': 609,
#  'growing': 610,
#  'senior': 611,
#  'cards': 612,
#  'west': 613,
#  'needs': 614,
#  'age': 615,
#  'create': 616,
#  'gaming': 617,
#  'iraq': 618,
#  'launched': 619,
#  'manchester': 620,
#  'box': 621,
#  'reported': 622,
#  '2000': 623,
#  'september': 624,
#  'release': 625,
#  'denied': 626,
#  'card': 627,
#  'late': 628,
#  'believes': 629,
#  'round': 630,
#  'arsenal': 631,
#  'weekend': 632,
#  'summer': 633,
#  'that': 634,
#  'mean': 635,
#  'simply': 636,
#  'products': 637,
#  'euros': 638,
#  'devices': 639,
#  'hours': 640,
#  'martin': 641,
#  'anything': 642,
#  '13': 643,
#  'dr': 644,
#  'changes': 645,
#  'reports': 646,
#  'range': 647,
#  'drive': 648,
#  'leading': 649,
#  'potential': 650,
#  'love': 651,
#  'hopes': 652,
#  'whole': 653,
#  'turn': 654,
#  'order': 655,
#  'russia': 656,
#  'champion': 657,
#  'spam': 658,
#  'seven': 659,
#  'value': 660,
#  'groups': 661,
#  'car': 662,
#  'pre': 663,
#  'parliament': 664,
#  'happy': 665,
#  'german': 666,
#  'energy': 667,
#  'fight': 668,
#  'similar': 669,
#  'idea': 670,
#  'position': 671,
#  'ensure': 672,
#  'sent': 673,
#  'message': 674,
#  'period': 675,
#  'singer': 676,
#  'irish': 677,
#  'squad': 678,
#  'windows': 679,
#  'either': 680,
#  '16': 681,
#  'street': 682,
#  'sport': 683,
#  'investors': 684,
#  'independent': 685,
#  'makes': 686,
#  'press': 687,
#  'attacks': 688,
#  '14': 689,
#  'test': 690,
#  'grand': 691,
#  'rose': 692,
#  'australian': 693,
#  'rock': 694,
#  'wrong': 695,
#  'school': 696,
#  'education': 697,
#  '2006': 698,
#  'robinson': 699,
#  'average': 700,
#  'conservative': 701,
#  'olympic': 702,
#  'fell': 703,
#  'association': 704,
#  'amount': 705,
#  'smith': 706,
#  'standard': 707,
#  'talks': 708,
#  '24': 709,
#  'sector': 710,
#  'bring': 711,
#  'oscar': 712,
#  'helped': 713,
#  'pressure': 714,
#  'stand': 715,
#  'exchange': 716,
#  'audience': 717,
#  'community': 718,
#  'provide': 719,
#  'workers': 720,
#  'selling': 721,
#  'private': 722,
#  'target': 723,
#  'results': 724,
#  'systems': 725,
#  'entertainment': 726,
#  'particularly': 727,
#  'compared': 728,
#  'proposals': 729,
#  'bought': 730,
#  'hand': 731,
#  'areas': 732,
#  'lords': 733,
#  'germany': 734,
#  'force': 735,
#  'numbers': 736,
#  'sell': 737,
#  'per': 738,
#  'accused': 739,
#  'attack': 740,
#  'speaking': 741,
#  'charge': 742,
#  'scottish': 743,
#  'speed': 744,
#  'via': 745,
#  'front': 746,
#  'moment': 747,
#  'speech': 748,
#  'fraud': 749,
#  'meanwhile': 750,
#  'worked': 751,
#  'opportunity': 752,
#  'brought': 753,
#  'special': 754,
#  'civil': 755,
#  'night': 756,
#  'spend': 757,
#  'official': 758,
#  'survey': 759,
#  'bit': 760,
#  'appeal': 761,
#  'shot': 762,
#  'history': 763,
#  'revealed': 764,
#  'bad': 765,
#  'download': 766,
#  'laws': 767,
#  'takes': 768,
#  'turned': 769,
#  're': 770,
#  'extra': 771,
#  'terms': 772,
#  'generation': 773,
#  'opposition': 774,
#  'poll': 775,
#  'australia': 776,
#  'battle': 777,
#  'agency': 778,
#  'off': 779,
#  'designed': 780,
#  'mini': 781,
#  'increased': 782,
#  'white': 783,
#  'chart': 784,
#  'forced': 785,
#  'concerns': 786,
#  'minute': 787,
#  'decided': 788,
#  'debate': 789,
#  'immigration': 790,
#  'course': 791,
#  'him': 792,
#  'analyst': 793,
#  'millions': 794,
#  'lives': 795,
#  'spent': 796,
#  'staff': 797,
#  'becoming': 798,
#  'attempt': 799,
#  'ban': 800,
#  'area': 801,
#  'defence': 802,
#  'cross': 803,
#  'admitted': 804,
#  'captain': 805,
#  'risk': 806,
#  '19': 807,
#  'reached': 808,
#  'central': 809,
#  'concerned': 810,
#  'levels': 811,
#  'widely': 812,
#  'hollywood': 813,
#  'step': 814,
#  'comedy': 815,
#  'commons': 816,
#  'followed': 817,
#  'became': 818,
#  'messages': 819,
#  'fund': 820,
#  'often': 821,
#  'threat': 822,
#  'screen': 823,
#  'air': 824,
#  'everyone': 825,
#  'pcs': 826,
#  'comments': 827,
#  'matter': 828,
#  'university': 829,
#  'story': 830,
#  'tough': 831,
#  'department': 832,
#  'included': 833,
#  'authorities': 834,
#  'james': 835,
#  'musical': 836,
#  'gave': 837,
#  'g': 838,
#  'build': 839,
#  'programs': 840,
#  'technologies': 841,
#  'impact': 842,
#  'process': 843,
#  'non': 844,
#  'gone': 845,
#  'voters': 846,
#  'charges': 847,
#  'rest': 848,
#  'remains': 849,
#  'view': 850,
#  'confidence': 851,
#  'businesses': 852,
#  'song': 853,
#  'machines': 854,
#  'believed': 855,
#  'premiership': 856,
#  'poor': 857,
#  'alan': 858,
#  'ask': 859,
#  'finance': 860,
#  'original': 861,
#  'east': 862,
#  'nominated': 863,
#  '22': 864,
#  'reach': 865,
#  'bush': 866,
#  'allowed': 867,
#  'markets': 868,
#  'tsunami': 869,
#  'created': 870,
#  'organisation': 871,
#  'building': 872,
#  '£1': 873,
#  'experience': 874,
#  'whose': 875,
#  'date': 876,
#  'soon': 877,
#  'member': 878,
#  'debut': 879,
#  'euro': 880,
#  'credit': 881,
#  'cuts': 882,
#  'indian': 883,
#  'named': 884,
#  'scheme': 885,
#  'j': 886,
#  'drugs': 887,
#  'mike': 888,
#  'theatre': 889,
#  'nine': 890,
#  'hour': 891,
#  'june': 892,
#  'domestic': 893,
#  'newspaper': 894,
#  'quality': 895,
#  'leave': 896,
#  'unit': 897,
#  'majority': 898,
#  'figure': 899,
#  'officials': 900,
#  'worth': 901,
#  'recovery': 902,
#  'so': 903,
#  'b': 904,
#  'titles': 905,
#  'challenge': 906,
#  'everything': 907,
#  'andy': 908,
#  'row': 909,
#  'rival': 910,
#  'care': 911,
#  'management': 912,
#  'cases': 913,
#  'offered': 914,
#  'kennedy': 915,
#  'trust': 916,
#  'response': 917,
#  'champions': 918,
#  'gold': 919,
#  'critics': 920,
#  'body': 921,
#  'illegal': 922,
#  'fast': 923,
#  'light': 924,
#  'shown': 925,
#  'anyone': 926,
#  'code': 927,
#  'insisted': 928,
#  'account': 929,
#  'outside': 930,
#  'r': 931,
#  'peer': 932,
#  'deutsche': 933,
#  'example': 934,
#  'crime': 935,
#  'all': 936,
#  'focus': 937,
#  'april': 938,
#  'kept': 939,
#  'rising': 940,
#  'states': 941,
#  'met': 942,
#  'successful': 943,
#  'winner': 944,
#  'clarke': 945,
#  'raise': 946,
#  'zealand': 947,
#  'deficit': 948,
#  'post': 949,
#  'situation': 950,
#  'newcastle': 951,
#  'taxes': 952,
#  'trading': 953,
#  'america': 954,
#  'moved': 955,
#  'mp': 956,
#  'spain': 957,
#  'couple': 958,
#  'confirmed': 959,
#  'robert': 960,
#  'question': 961,
#  'mac': 962,
#  'computers': 963,
#  'watch': 964,
#  'built': 965,
#  'park': 966,
#  'serious': 967,
#  'previously': 968,
#  '27': 969,
#  'easy': 970,
#  'banks': 971,
#  'significant': 972,
#  'pop': 973,
#  'text': 974,
#  'penalty': 975,
#  'madrid': 976,
#  'approach': 977,
#  'gm': 978,
#  'protection': 979,
#  'machine': 980,
#  'probably': 981,
#  'files': 982,
#  'programmes': 983,
#  'host': 984,
#  'daily': 985,
#  'bankruptcy': 986,
#  'planning': 987,
#  'signed': 988,
#  'johnson': 989,
#  'judge': 990,
#  'de': 991,
#  'ray': 992,
#  'exports': 993,
#  'double': 994,
#  'looks': 995,
#  'favourite': 996,
#  'suggested': 997,
#  'leaders': 998,
#  'north': 999,
#  'defeat': 1000,
#  ...}

# %%
tokenizer.texts_to_sequences(['the cat sat on my table'])
# Out:
# [[1300, 1, 1, 576, 1, 2888]]

# %%
train_sequences = tokenizer.texts_to_sequences(train_articles)
len(train_sequences)
# Out:
# 1469

# %%
train_sequences[0]
# Out:
# [86,
#  162,
#  1111,
#  1071,
#  48,
#  889,
#  725,
#  1,
#  80,
#  1215,
#  4676,
#  113,
#  152,
#  3625,
#  1341,
#  1264,
#  1476,
#  42,
#  7,
#  964,
#  86,
#  1,
#  346,
#  87,
#  19,
#  13,
#  127,
#  2934,
#  1093,
#  2572,
#  567,
#  406,
#  1342,
#  54,
#  3161,
#  3310,
#  1553,
#  8,
#  841,
#  842,
#  10,
#  996,
#  1,
#  9,
#  649,
#  1527,
#  983,
#  323,
#  1878,
#  1071,
#  745,
#  48,
#  469,
#  1343,
#  1751,
#  1606,
#  121,
#  255,
#  101,
#  2257,
#  746,
#  4677,
#  1112,
#  639,
#  10,
#  3797,
#  4183,
#  841,
#  2489,
#  113,
#  347,
#  152,
#  3625,
#  1,
#  4678,
#  41,
#  72,
#  2573,
#  29,
#  9,
#  1,
#  18,
#  1161,
#  120,
#  411,
#  7,
#  156,
#  1244,
#  70,
#  4184,
#  460,
#  4679,
#  86,
#  983,
#  73,
#  1,
#  74,
#  2327,
#  53,
#  1,
#  86,
#  6,
#  965,
#  595,
#  80,
#  1215,
#  86,
#  1988,
#  131,
#  129,
#  393,
#  9,
#  2574,
#  38,
#  163,
#  1245,
#  80,
#  1215,
#  1,
#  7,
#  460,
#  4679,
#  3162,
#  6,
#  2575,
#  1,
#  381,
#  1072,
#  1,
#  1374,
#  562,
#  1344,
#  2196,
#  1,
#  726,
#  9,
#  469,
#  1343,
#  1751,
#  121,
#  1989,
#  362,
#  772,
#  1800,
#  1801,
#  37,
#  1607,
#  2826,
#  1,
#  4680,
#  2078,
#  240,
#  9,
#  2490,
#  74,
#  747,
#  6,
#  1186,
#  1290,
#  163,
#  727,
#  610,
#  1,
#  114,
#  29,
#  1161,
#  1577,
#  412,
#  77,
#  890,
#  116,
#  19,
#  13,
#  18,
#  2935,
#  1,
#  35,
#  1401,
#  1,
#  23,
#  35,
#  90,
#  340,
#  2258,
#  35,
#  466,
#  260,
#  1800,
#  1314,
#  318,
#  1,
#  314,
#  747,
#  1094,
#  18,
#  2576,
#  1607,
#  4680,
#  274,
#  825,
#  1095,
#  323,
#  1802,
#  394,
#  381,
#  1802,
#  2,
#  1345,
#  1,
#  1607,
#  2079,
#  57,
#  1,
#  1,
#  1528,
#  255,
#  1719,
#  3464,
#  1073,
#  323,
#  39,
#  906,
#  247,
#  2577,
#  321,
#  53,
#  518,
#  362,
#  2,
#  1,
#  1,
#  611,
#  1187,
#  191,
#  86,
#  3626,
#  86,
#  92,
#  42,
#  7,
#  324,
#  323,
#  73,
#  964,
#  1,
#  86,
#  1071,
#  362,
#  469,
#  9,
#  772,
#  2078,
#  11,
#  38,
#  1,
#  1096,
#  467,
#  478,
#  2659,
#  162,
#  548,
#  1,
#  146,
#  7,
#  324,
#  73,
#  964,
#  1127,
#  1072,
#  1448,
#  363,
#  50,
#  1929,
#  1162,
#  773,
#  99,
#  251,
#  270,
#  1291,
#  70,
#  588,
#  363,
#  2328,
#  825,
#  1093,
#  2124,
#  1720,
#  1,
#  3999,
#  3798,
#  1,
#  1072,
#  1802,
#  170,
#  372,
#  1402,
#  73,
#  53,
#  518,
#  97,
#  1111,
#  3,
#  1,
#  997,
#  91,
#  3046,
#  1,
#  2827,
#  1,
#  107,
#  907,
#  423,
#  417,
#  2,
#  3,
#  1,
#  2747,
#  406,
#  1375,
#  47,
#  73,
#  442,
#  31,
#  8,
#  1291,
#  841,
#  1,
#  2489,
#  28,
#  1,
#  86,
#  1578,
#  874,
#  80,
#  1215,
#  86,
#  1988,
#  1,
#  28,
#  8,
#  1879,
#  1,
#  1,
#  3799,
#  1608,
#  4676,
#  619,
#  1,
#  3311,
#  965,
#  548,
#  4185,
#  2573,
#  10,
#  934,
#  619,
#  54,
#  1,
#  1216,
#  1,
#  1,
#  86,
#  1500,
#  891,
#  1,
#  1,
#  523,
#  4000,
#  10,
#  9,
#  233,
#  1751,
#  86,
#  121,
#  1,
#  100,
#  619,
#  3627,
#  1,
#  54,
#  603,
#  640,
#  2660,
#  3311,
#  1,
#  2936,
#  478,
#  4681,
#  41,
#  4184,
#  1,
#  86,
#  1681,
#  640,
#  235,
#  110,
#  275,
#  2578,
#  374,
#  663,
#  54,
#  4186,
#  748,
#  3800,
#  1,
#  154,
#  1,
#  362,
#  7,
#  70,
#  1880,
#  983,
#  679,
#  826,
#  134,
#  639,
#  3312,
#  1292,
#  1527,
#  1,
#  1554,
#  7,
#  964,
#  73,
#  73]

# %%
train_padded = pad_sequences(train_sequences, maxlen=max_length)  # padding every record into specific lenght 200

# %%
train_padded
# Out:
# array([[  53,  518,  362, ...,  964,   73,   73],
#        [   0,    0,    0, ...,    1, 2197,    1],
#        [   0,    0,    0, ..., 1138,   25, 1611],
#        ...,
#        [   0,    0,    0, ...,  544,    1,    1],
#        [   0,    0,    0, ...,  130,  901,    1],
#        [ 842, 1047, 4875, ...,  448, 3939,  733]], dtype=int32)

# %%
len(train_padded),len(train_padded[0])
# Out:
# (1469, 200)

# %%
validation_sequences = tokenizer.texts_to_sequences(validation_articles)
validation_padded = pad_sequences(validation_sequences, maxlen=max_length)

# %%
set(labels)
# Out:
# {'business', 'entertainment', 'politics', 'sport', 'tech'}

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

training_label_seq = label_encoder.fit_transform(train_labels)
validation_label_seq = label_encoder.fit_transform(validation_labels)

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight('balanced', classes=np.unique(training_label_seq), y=training_label_seq)
class_weight_dict = dict(zip(np.unique(training_label_seq), class_weights))

# %%
# from tensorflow.keras.callbacks import EarlyStopping

# early_stopping = EarlyStopping(monitor='val_accuracy', patience=3, restore_best_weights=True)

# %%
train_labels[0], training_label_seq[0]
# Out:
# ('tech', np.int64(4))

# %%
from tensorflow.keras.layers import LSTM, Bidirectional

model = Sequential()

# Embedding layer
model.add(Embedding(vocab_size, embedding_dim, input_length=max_length))
model.add(Dropout(0.4))

# Convolutional Layer (optional: keep if you want to extract local patterns before LSTM)
model.add(Conv1D(filters=64, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

# Bidirectional LSTM layer
model.add(Bidirectional(LSTM(units=64, return_sequences=True)))  # return_sequences=True to allow stacking
model.add(Dropout(0.4))

# Another Bidirectional LSTM layer
model.add(Bidirectional(LSTM(units=64)))
model.add(Dropout(0.4))

# Batch Normalization
model.add(BatchNormalization())

# Dense layer
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.4))

# Output layer (5 classes)
model.add(Dense(5, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
opt = Adam(learning_rate=0.0003)
model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
num_epochs = 30
history = model.fit(train_padded, training_label_seq,
                    epochs=num_epochs,
                    validation_data=(validation_padded, validation_label_seq),
                    class_weight=class_weight_dict, verbose=2)
# Out:
# Epoch 1/30
# 46/46 - 14s - 298ms/step - accuracy: 0.2444 - loss: 1.6434 - val_accuracy: 0.2283 - val_loss: 1.6029
# Epoch 2/30
# 46/46 - 1s - 22ms/step - accuracy: 0.2961 - loss: 1.5409 - val_accuracy: 0.2717 - val_loss: 1.5966
# Epoch 3/30
# 46/46 - 1s - 26ms/step - accuracy: 0.4112 - loss: 1.3694 - val_accuracy: 0.4620 - val_loss: 1.5716
# Epoch 4/30
# 46/46 - 2s - 36ms/step - accuracy: 0.5548 - loss: 1.0516 - val_accuracy: 0.6413 - val_loss: 1.4431
# Epoch 5/30
# 46/46 - 1s - 26ms/step - accuracy: 0.7502 - loss: 0.6098 - val_accuracy: 0.7582 - val_loss: 1.0054
# Epoch 6/30
# 46/46 - 1s - 21ms/step - accuracy: 0.8856 - loss: 0.3240 - val_accuracy: 0.8940 - val_loss: 0.5960
# Epoch 7/30
# 46/46 - 1s - 22ms/step - accuracy: 0.9517 - loss: 0.1685 - val_accuracy: 0.9266 - val_loss: 0.4748
# Epoch 8/30
# 46/46 - 1s - 22ms/step - accuracy: 0.9762 - loss: 0.1030 - val_accuracy: 0.9429 - val_loss: 0.2082
# Epoch 9/30
# 46/46 - 1s - 21ms/step - accuracy: 0.9932 - loss: 0.0481 - val_accuracy: 0.9022 - val_loss: 0.2829
# Epoch 10/30
# 46/46 - 1s - 22ms/step - accuracy: 0.9912 - loss: 0.0481 - val_accuracy: 0.9293 - val_loss: 0.2221
# Epoch 11/30
# 46/46 - 1s - 27ms/step - accuracy: 0.9939 - loss: 0.0344 - val_accuracy: 0.8995 - val_loss: 0.3062
# Epoch 12/30
# 46/46 - 1s - 27ms/step - accuracy: 0.9959 - loss: 0.0302 - val_accuracy: 0.9511 - val_loss: 0.2101
# Epoch 13/30
# 46/46 - 1s - 22ms/step - accuracy: 0.9639 - loss: 0.1116 - val_accuracy: 0.8560 - val_loss: 0.3771
# Epoch 14/30
# 46/46 - 1s - 21ms/step - accuracy: 0.9952 - loss: 0.0297 - val_accuracy: 0.9484 - val_loss: 0.1701
# Epoch 15/30
# 46/46 - 2s - 39ms/step - accuracy: 0.9946 - loss: 0.0240 - val_accuracy: 0.9511 - val_loss: 0.1613
# Epoch 16/30
# 46/46 - 1s - 23ms/step - accuracy: 0.9966 - loss: 0.0157 - val_accuracy: 0.9185 - val_loss: 0.2657
# Epoch 17/30
# 46/46 - 1s - 21ms/step - accuracy: 0.9986 - loss: 0.0130 - val_accuracy: 0.9484 - val_loss: 0.1981
# Epoch 18/30
# 46/46 - 1s - 28ms/step - accuracy: 0.9986 - loss: 0.0089 - val_accuracy: 0.9538 - val_loss: 0.2123
# Epoch 19/30
# 46/46 - 1s - 27ms/step - accuracy: 0.9980 - loss: 0.0092 - val_accuracy: 0.9674 - val_loss: 0.2142
# Epoch 20/30
# 46/46 - 1s - 21ms/step - accuracy: 0.9952 - loss: 0.0226 - val_accuracy: 0.7364 - val_loss: 1.1339
# Epoch 21/30
# 46/46 - 1s - 21ms/step - accuracy: 0.9809 - loss: 0.0636 - val_accuracy: 0.9348 - val_loss: 0.2437
# Epoch 22/30
# 46/46 - 1s - 27ms/step - accuracy: 0.9932 - loss: 0.0256 - val_accuracy: 0.9402 - val_loss: 0.2189
# Epoch 23/30
# 46/46 - 1s - 21ms/step - accuracy: 0.9980 - loss: 0.0122 - val_accuracy: 0.9429 - val_loss: 0.2435
# Epoch 24/30
# 46/46 - 1s - 21ms/step - accuracy: 0.9986 - loss: 0.0088 - val_accuracy: 0.9592 - val_loss: 0.1657
# Epoch 25/30
# 46/46 - 1s - 29ms/step - accuracy: 0.9993 - loss: 0.0063 - val_accuracy: 0.9565 - val_loss: 0.1690
# Epoch 26/30
# 46/46 - 1s - 28ms/step - accuracy: 0.9986 - loss: 0.0080 - val_accuracy: 0.9674 - val_loss: 0.2064
# Epoch 27/30
# 46/46 - 2s - 49ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9674 - val_loss: 0.1755
# Epoch 28/30
# 46/46 - 1s - 22ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9592 - val_loss: 0.1730
# Epoch 29/30
# 46/46 - 1s - 27ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9647 - val_loss: 0.1783
# Epoch 30/30
# 46/46 - 1s - 21ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9647 - val_loss: 0.1891

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
txt = ["blair prepares to name poll date tony blair is likely to name 5 may as election day when parliament returns from its easter break  the bbc s political editor has learned.  andrew marr says mr blair will ask the queen on 4 or 5 april to dissolve parliament at the end of that week. mr blair has so far resisted calls for him to name the day but all parties have stepped up campaigning recently. downing street would not be drawn on the claim  saying election timing was a matter for the prime minister.  a number 10 spokeswoman would only say:  he will announce an election when he wants to announce an election.  the move will signal a frantic week at westminster as the government is likely to try to get key legislation through parliament. the government needs its finance bill  covering the budget plans  to be passed before the commons closes for business at the end of the session on 7 april.  but it will also seek to push through its serious and organised crime bill and id cards bill. mr marr said on wednesday s today programme:  there s almost nobody at a senior level inside the government or in parliament itself who doesn t expect the election to be called on 4 or 5 april.  as soon as the commons is back after the short easter recess  tony blair whips up to the palace  asks the queen to dissolve parliament ... and we re going.  the labour government officially has until june 2006 to hold general election  but in recent years governments have favoured four-year terms."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
labels = ['bussiness', 'entertainment', 'politics', 'sport', 'tech']

print(pred)
print(np.argmax(pred))
print(labels[np.argmax(pred)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# [[7.9925385e-06 2.8784709e-05 9.9992490e-01 8.2009456e-07 3.7382459e-05]]
# 2
# politics

# %%
txt = ["call to save manufacturing jobs the trades union congress (tuc) is calling on the government to stem job losses in manufacturing firms by reviewing the help it gives companies.  the tuc said in its submission before the budget that action is needed because of 105 000 jobs lost from the sector over the last year. it calls for better pensions  child care provision and decent wages. the 36-page submission also urges the government to examine support other european countries provide to industry. tuc general secretary brendan barber called for  a commitment to policies that will make a real difference to the lives of working people.    greater investment in childcare strategies and the people delivering that childcare will increases the options available to working parents   he said.  a commitment to our public services and manufacturing sector ensures that we can continue to compete on a global level and deliver the frontline services that this country needs.  he also called for  practical measures  to help pensioners  especially women who he said  are most likely to retire in poverty . the submission also calls for decent wages and training for people working in the manufacturing sector."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
labels = ['bussiness', 'entertainment', 'politics', 'sport', 'tech']

print(pred)
print(np.argmax(pred))
print(labels[np.argmax(pred)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[9.8745954e-01 2.9295331e-03 2.9197235e-03 4.2662740e-04 6.2645320e-03]]
# 0
# bussiness
